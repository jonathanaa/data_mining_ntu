# %%
#coding:utf-8
import matplotlib.pyplot as plt
import matplotlib
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
from matplotlib.font_manager import FontProperties
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 
plt.rcParams['axes.unicode_minus'] = False

# %%
dimension = [1,5,10,30,50,100,200,500]
pca_svm = [0.31510,0.77280,0.93640,0.98030,0.98330,0.98410,0.98290,0.98240]
nmf_svm=[0.20456,0.7054,0.8815,0.9715,0.9781,0.9765,0.9739,0.967]

# %%
plt.figure(figsize=(5,3),dpi=100,linewidth=2)
plt.plot(dimension,pca_svm,'s-',color = 'r', label="PCA+SVM")
plt.plot(dimension,nmf_svm,'o-',color = 'g', label="NMF+SVM")
plt.title(u'經過PCA、NMF降維在SVM下之準確率', x=0.5, y=1.03)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("dimension", fontsize=15, labelpad = 15)
plt.ylabel("accuracy", fontsize=15, labelpad = 15)
plt.legend(loc = "best", fontsize=10)
plt.show()

# %%
dimension = [1,5,10,30,50,100,200,500]
pca_knn = [0.27380,0.74750,0.92760,0.97540,0.97490,0.97270,0.96980,0.96870]
nmf_knn=[0.1648,0.667,0.8647,0.9558,0.9508,0.9508,0.9396,0.9091]

plt.figure(figsize=(5,3),dpi=100,linewidth=2)
plt.plot(dimension,pca_knn,'s-',color = 'r', label="PCA+KNN")
plt.plot(dimension,nmf_knn,'o-',color = 'g', label="NMF+KNN")
plt.title(u'經過PCA、NMF降維在KNN下之準確率', x=0.5, y=1.03)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("dimension", fontsize=15, labelpad = 15)
plt.ylabel("accuracy", fontsize=15, labelpad = 15)
plt.legend(loc = "best", fontsize=10)
plt.show()

# %%
dimension = [1,5,10,30,50,100,200,500]
pca_deci = [0.24870,0.66930,0.82380,0.84900,0.84340,0.84030,0.83020,0.82000]
nmf_deci=[0.147,0.6116,0.7993,0.8811,0.8697,0.8663,0.8676,0.8425]

plt.figure(figsize=(5,3),dpi=100,linewidth=2)
plt.plot(dimension,pca_deci,'s-',color = 'r', label="PCA+DecisionTree")
plt.plot(dimension,nmf_deci,'o-',color = 'g', label="NMF+DecisionTree")
plt.title(u'經過PCA、NMF降維在DecisionTree下之準確率', x=0.5, y=1.03)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("dimension", fontsize=15, labelpad = 15)
plt.ylabel("accuracy", fontsize=15, labelpad = 15)
plt.legend(loc = "best", fontsize=10)
plt.show()

# %%
dimension = [1,5,10,30,50,100,200,500]
pca_ran = [0.24880,0.76280,0.91390,0.95380,0.95540,0.95150,0.94620,0.92300]
nmf_ran=[0.1471,0.7039,0.8872,0.9596,0.9655,0.9654,0.9644,0.9624]

plt.figure(figsize=(5,3),dpi=100,linewidth=2)
plt.plot(dimension,pca_ran,'s-',color = 'r', label="PCA+RandomForest")
plt.plot(dimension,nmf_ran,'o-',color = 'g', label="NMF+RandomForest")
plt.title(u'經過PCA、NMF降維在RandomForest下之準確率', x=0.5, y=1.03)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("dimension", fontsize=15, labelpad = 15)
plt.ylabel("accuracy", fontsize=15, labelpad = 15)
plt.legend(loc = "best", fontsize=10)
plt.show()
